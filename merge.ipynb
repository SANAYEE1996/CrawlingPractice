# %%
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
import codecs
codecs.register(lambda name: codecs.lookup('utf8') if name == 'utf8mb4' else None)

# %%
data = pd.read_csv('C:/Users/user2/Downloads/carAD22.csv' , sep=',' , encoding = 'utf8', index_col = 0)

# %%
data.columns = ['url', 'foreign', 'comment']

# %%
data
# Out:
#              url   foreign                                            comment
# 0    SuEHXSNoexE  0.000000  오늘은 다이렉트 자동차보험 비교 전문기업인 애드인슈에서 퀴즈 협찬을 해주셨습니다.\...
# 1    sZvuYayyVa0  0.000000  보행자가 분명 블박차 쪽을\n확인 한 것 같은데 ....\n왜 뛰어 나오지...?마...
# 2    CwVfA2pfYPo  0.000000  저걸 2주 나왔다고 한다면 저 사람은 방지턱 넘으면 사망 하겠네요 저건 100% 보...
# 3    _kkrIwZCsRY  0.000000  저상황이면 카니발이 뒤로 후진하는게 정상아닌가 ?여성이라고 배려해줄필요 없습니다. ...
# 4    Z6sYs1h44PI  0.012658  와... 씨... 이걸 어케 피했데ㄷㄷㄷ\n\n진짜 대단하다고밖에...아 이거보고 ...
# 5    X5P5APcOCsU  0.006975  이번건 진짜 오토바이 과실없다...\n택시 미쳤네 진짜실선 밟고 가셨으니 택시 10...
# 6    dMsR0kvZL_4  0.002732  진짜 잘 박았습니다.  저거 피해줬으면 나 혼자 사고나고 저 차는 그냥 갈겁니다저걸...
# 7    VdhcNmuGhpw  0.000505  저렇게 보호해줄꺼면 비보호 없애자...아니 ㅆ발 무단횡단해도 보상받는데 인도에있는 ...
# 8         #NAME?  0.000000                                                NaN
# 9    03GDQ9qfMQ8  0.000000  죽고  싶으면  남에게 피해주지 말고   조용하게  깔금하게 혼자,,,,자전거 역주...
# 10   MfWK7w4dXak  0.002128  블박 보네주신 분은 ㄹㅇ 은인이다항상 경찰은 변호사님과 구독자들에게 토론을 하게끔 ...
# ...

# %%
engine = create_engine('mysql+mysqlconnector://root:root1234@ec2-15-164-48-78.ap-northeast-2.compute.amazonaws.com:3306/anoter?charset=utf8mb4')

# %%
data.to_sql(name='test', con = engine, if_exists='append', index = False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     688     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 689         cursor.executemany(statement, parameters)
#     690
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor.py in executemany(self, operation, seq_params)
#     653             if stmt is not None:
# --> 654                 return self.execute(stmt)
#     655
#
# ...
